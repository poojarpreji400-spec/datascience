# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import silhouette_score

# %%
data = pd.read_csv(r'C:\Users\POOJA\Downloads\Mall_Customers.csv')
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
print(data.head())
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print(data.describe())
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
print(data.isnull().sum())
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
le = LabelEncoder()
data['Genre'] = le.fit_transform(data['Genre'])

# %%
scaler = StandardScaler()
features = data[['Genre', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
x_scaled = scaler.fit_transform(features)

# %%
inertia = []
for k in range(1,11):
    kmeans = KMeans(n_clusters = k, random_state = 42)
    kmeans.fit(x_scaled)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize = (6,4))
plt.plot(range(1,11), inertia, marker = 'o')
plt.title('Elbow method')
plt.xlabel('number of clusters')
plt.ylabel('inertia')
plt.show()

# %% [markdown]
# k = 5

# %%
kmeans1 = KMeans(n_clusters = 5, random_state = 42)
clusters = kmeans1.fit_predict(x_scaled)
data['clusters'] = clusters

# %%
sil_score = silhouette_score(x_scaled, clusters)
print(sil_score)
# Out:
# 0.27191023466188324

# %%
pca = PCA(n_components = 2)
x_pca = pca.fit_transform(x_scaled)
data['pca1'] = x_pca[:,0]
data['pca2'] = x_pca[:,1]
plt.figure(figsize = (6,4))
sns.scatterplot(x = 'pca1',y = 'pca2', hue = 'clusters',data = data, palette = 'Set1' )
plt.title('mall customers visulaization using PCA')
plt.show()

# %%
new_customers = [[1,25,40,60]]
new_customers_scaled = scaler.transform(new_customers)
predicted_cluster = kmeans1.predict(new_customers_scaled)
print('predicted cluster', predicted_cluster[0])
# Out:
# predicted cluster 2
# c:\Users\POOJA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2830: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
cluster_2 = data[data['clusters'] == 2]
print(cluster_2)
print(cluster_2[['Genre', 'Age','Annual Income (k$)','Spending Score (1-100)']].mean())
# Out:
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1      1   19                  15                      39
# 1             2      1   21                  15                      81
# 15           16      1   22                  20                      79
# 17           18      1   20                  21                      66
# 20           21      1   35                  24                      35
# 21           22      1   25                  24                      73
# 23           24      1   31                  25                      73
# 25           26      1   29                  28                      82
# 27           28      1   35                  28                      61
# 33           34      1   18                  33                      92
# 41           42      1   24                  38                      92
# 51           52      1   33                  42                      60
# ...
